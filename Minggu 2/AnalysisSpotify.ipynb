# %% [markdown]
# ## Memuat Data

# %%
# import library
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os
for dirname, _, filenames in os.walk('spotify_top_songs_audio_datasets.csv'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
song_df = pd.read_csv("spotify_top_songs_audio_datasets.csv")

# %%
# Menampilkan 10 baris data awal dari dataset
song_df.head(10)
# Out:
#                        id                                       artist_names  \
# 0  000xQL6tZNLJzIrtIgxqSl                                ZAYN, PARTYNEXTDOOR
# 1  003eoIwxETJujVWmNFMoZy                                       Alessia Cara
# 2  003vvx7Niy0yvhvHt4a68B                                        The Killers
# 3  00B7TZ0Xawar6NZ00JFomN                         Cardi B, Chance the Rapper
# 4  00Blm7zeNqgYLPtW6zg8cj                            Post Malone, The Weeknd
# 5  00EPIEnX1JFjff8sC6bccd                              Thalia, NATTI NATASHA
# 6  00ETaeHUQ6lops3oWU1Wrt                                 Kygo, Donna Summer
# 7  00ZKeP47bZtswtANkvxz2j  Tropa do Bruxo, DJ Ws da Igrejinha, SMU, Triz,...
# 8  00gpGR84M27moP7AFuqHIx                                         YBN Nahmir
# 9  00imgaPlYRrMGn9o83hfmk                                       Brent Faiyaz
#
#                              track_name  \
# 0  Still Got Time (feat. PARTYNEXTDOOR)
# ...

# %%
# Menampilkan 10 baris data akhir dari dataset
song_df.tail(10)
# Out:
#                           id  \
# 6503  7z4xW9WY86uH3gd1V9pfCM
# 6504  7zBscbZUCr4jEABrfV9g03
# 6505  7zQirOExB0VR8yWUOqYeio
# 6506  7zTx8ePYAmPFQuxP3xlXZn
# 6507  7zVCrzzEJU7u24sbJPXA5W
# 6508  7zgqtptZvhf8GEmdsM2vp2
# 6509  7zjEyeBsaw9gV0jofJLfOM
# 6510  7zl7kehxesNEo2pYkKXTSe
# 6511  7zvfDihYiJ8RQ1nRcpKBF5
# 6512  7zxRMhXxJMQCeDDg0rKAVo
#
#                                            artist_names  \
# 6503  Tyler, The Creator, Lil Uzi Vert, Pharrell Wil...
# 6504                                               Joji
# 6505                     Lil Nas X, Megan Thee Stallion
# 6506                                           San Holo
# 6507                          Kane Brown, Lauren Alaina
# 6508                                       Taylor Swift
# 6509                Young Thug, A$AP Rocky, Post Malone
# 6510                        Eminem, Jack Harlow, Cordae
# 6511                        Kendrick Lamar, Tanna Leone
# 6512                                    NAV, The Weeknd
#
# ...

# %% [markdown]
# ## Menelaah Data

# %%
# Mengungkap tipe-tipe data dari setiap kolom
print(song_df.dtypes)
# Out:
# id                   object
# artist_names         object
# track_name           object
# source               object
# key                  object
# mode                 object
# time_signature       object
# danceability        float64
# energy              float64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# loudness            float64
# tempo               float64
# duration_ms           int64
# weeks_on_chart        int64
# streams               int64
# dtype: object

# %%
# Mengungkap informasi dataset
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6513 entries, 0 to 6512
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                6513 non-null   object
#  1   artist_names      6513 non-null   object
#  2   track_name        6513 non-null   object
#  3   source            6513 non-null   object
#  4   key               6513 non-null   object
#  5   mode              6513 non-null   object
#  6   time_signature    6513 non-null   object
#  7   danceability      6513 non-null   float64
#  8   energy            6513 non-null   float64
#  9   speechiness       6513 non-null   float64
#  10  acousticness      6513 non-null   float64
#  11  instrumentalness  6513 non-null   float64
#  12  liveness          6513 non-null   float64
#  13  valence           6513 non-null   float64
#  14  loudness          6513 non-null   float64
#  15  tempo             6513 non-null   float64
# ...

# %%
# Menampilkan statistik dasar setiap kolom data yang bertipe numerik.
song_df.describe()
# Out:
#        danceability       energy  speechiness  acousticness  instrumentalness  \
# count   6513.000000  6513.000000  6513.000000   6513.000000       6513.000000
# mean       0.681731     0.636522     0.121933      0.236761          0.012469
# std        0.141787     0.164813     0.113441      0.244784          0.075151
# min        0.150000     0.021800     0.023200      0.000008          0.000000
# 25%        0.591000     0.534000     0.044000      0.044400          0.000000
# 50%        0.698000     0.651000     0.072200      0.145000          0.000000
# 75%        0.785000     0.759000     0.163000      0.356000          0.000041
# max        0.985000     0.989000     0.966000      0.994000          0.953000
#
#           liveness      valence     loudness        tempo    duration_ms  \
# count  6513.000000  6513.000000  6513.000000  6513.000000    6513.000000
# mean      0.180168     0.492412    -6.350667   122.117244  202566.684170
# ...

# %%
# Menampilkan 5 baris teratas berdasarkan total jumlah stream
artist_streams = song_df.groupby('artist_names')['streams'].sum().sort_values(ascending=False)
artist_streams.head()
# Out:
# artist_names
# Taylor Swift    15388585740
# Ed Sheeran      13111071610
# The Weeknd      11184004532
# Bad Bunny       10532229467
# Harry Styles     9661158399
# Name: streams, dtype: int64

# %%
# Menampilkan 5 baris teratas awal yang diurutkan berdasarkan kolom 'streams'
streams5=song_df.sort_values(by ='streams',ascending=False).head(5)
song_df.sort_values(by ='streams',ascending=False).head()
# Out:
#                           id   artist_names         track_name  \
# 435   0VjIjW4GlUZAMYd2vXMi3b     The Weeknd    Blinding Lights
# 6383  7qiZfU4dY1lWllzX7mPBI3     Ed Sheeran       Shape of You
# 6378  7qEHsqek33rTcFNT9PFqLf  Lewis Capaldi  Someone You Loved
# 748   0tgVpDi06FyKpA1z0VMD4v     Ed Sheeran            Perfect
# 3523  4Dvkj6JhhA12EX05fT7y2e   Harry Styles          As It Was
#
#                    source    key   mode time_signature  danceability  energy  \
# 435      Republic Records  C#/Db  Major        4 beats         0.514   0.730
# 6383  Atlantic Records UK  C#/Db  Minor        4 beats         0.825   0.652
# 6378       Vertigo Berlin  C#/Db  Major        4 beats         0.501   0.405
# 748   Atlantic Records UK  G#/Ab  Major        3 beats         0.599   0.448
# 3523             Columbia  F#/Gb  Minor        4 beats         0.520   0.731
#
#       speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
# Menampilkan duplikasi data dengan spesifik kolom
song_df.loc[song_df.duplicated(subset=['artist_names','track_name'])]
# Out:
#                           id                  artist_names  \
# 180   0D75ciM842cdUMKSMfAR9y  Selena Gomez, Rauw Alejandro
# 409   0UPBidRYcgJ2mjZlk08V8x                      Lil Tjay
# 449   0WdGQhoAP2LBsqr5Jhit2g                 Maroon 5, SZA
# 490   0Zm7NKJgoKY6ZWwtoEUILK                    Kanye West
# 524   0cLS7FslBJgsuWwJNRnPWB                  Lana Del Rey
# ...                      ...                           ...
# 6485  7y7w4tl4MaRC2UMEj1mPtr        Juice WRLD, Marshmello
# 6487  7yBEKiv1LmO7GM4rOejhcW                      ThxSoMch
# 6488  7yBbV2k2S2uhaQc24NF2xt                     Lady Gaga
# 6495  7yfi8B8opXjnRh4VZnOkz9                Jonas Brothers
# 6508  7zgqtptZvhf8GEmdsM2vp2                  Taylor Swift
#
#                                track_name  \
# 180   Baila Conmigo (with Rauw Alejandro)
# 409                                   F.N
# 449            What Lovers Do (feat. SZA)
# 490                            Praise God
# ...

# %%
# Mengecek data duplikat
song_df.query("track_name=='Baila Conmigo (with Rauw Alejandro)'")
# Out:
#                          id                  artist_names  \
# 102  079Ey5uxL04AKPQgVQwx5h  Selena Gomez, Rauw Alejandro
# 180  0D75ciM842cdUMKSMfAR9y  Selena Gomez, Rauw Alejandro
#
#                               track_name                      source key  \
# 102  Baila Conmigo (with Rauw Alejandro)  Selena Gomez Latin Project   F
# 180  Baila Conmigo (with Rauw Alejandro)  Selena Gomez Latin Project   F
#
#       mode time_signature  danceability  energy  speechiness  acousticness  \
# 102  Major        4 beats         0.823   0.544       0.0715        0.0215
# 180  Major        4 beats         0.824   0.545       0.0699        0.0221
#
#      instrumentalness  liveness  valence  loudness    tempo  duration_ms  \
# 102           0.00315    0.0966    0.664    -7.132  149.903       186088
# 180           0.00375    0.0970    0.683    -7.127  149.912       186088
#
#      weeks_on_chart    streams  duration_min
# 102              24  170621325      3.101467
# ...

# %%
# Menampilkan frekuensi setiap nilai unik di dalam kolom
song_df['artist_names'].value_counts()
# Out:
# artist_names
# Taylor Swift                     175
# Drake                            111
# BTS                               71
# Bad Bunny                         70
# Ariana Grande                     60
#                                 ...
# Becky G, NATTI NATASHA             1
# Shakira, Manuel Turizo             1
# Martin Garrix, Bono, The Edge      1
# Lauv, Julia Michaels               1
# Kendrick Lamar, Tanna Leone        1
# Name: count, Length: 3001, dtype: int64

# %%
song_df['time_signature'].value_counts()
# Out:
# time_signature
# 4 beats    6057
# 3 beats     324
# 5 beats     107
# 1            25
# Name: count, dtype: int64

# %% [markdown]
# - Tanda birama sejumlah besar lagu adalah 4 ketukan dengan 6057 hitungan

# %%
song_df['source'].value_counts()
# Out:
# source
# Columbia                               317
# Republic Records                       271
# Taylor Swift                           178
# Warner Records                         140
# Rimas Entertainment LLC                125
#                                       ...
# Lava Music/Republic Records              1
# Atlantic Records/ATG                     1
# Yung Baby Tate                           1
# Rhino/Warner Records                     1
# W.A.V.E. Recordings/EMPIRE/Atlantic      1
# Name: count, Length: 967, dtype: int64

# %%
song_df['duration_min'] = song_df['duration_ms'] / 60000
song_df['duration_min'].value_counts()
# Out:
# duration_min
# 3.405783    6
# 3.316217    6
# 3.503333    5
# 4.123783    5
# 2.904217    5
#            ..
# 3.034883    1
# 2.914350    1
# 2.510317    1
# 3.614883    1
# 2.996217    1
# Name: count, Length: 5460, dtype: int64

# %% [markdown]
# - Sebagian besar durasi lagu adalah 2,5 hingga 4,5 menit
# - 3.405 menit dan 3.316 menit dan merupakan durasi lagu yang paling umum

# %%
song_df['danceability'].value_counts()
# Out:
# danceability
# 0.746    35
# 0.736    33
# 0.795    32
# 0.747    30
# 0.671    30
#          ..
# 0.370     1
# 0.432     1
# 0.968     1
# 0.184     1
# 0.330     1
# Name: count, Length: 686, dtype: int64

# %%
song_df[song_df['danceability']==song_df['danceability'].max()]
# Out:
#                          id  artist_names          track_name  \
# 700  0qYW2jULeN9giEty0ee9Fy  MC Rogerinho  Botadinha Saliente
#
#                    source key   mode time_signature  danceability  energy  \
# 700  MC Rogerinho Oficial   C  Major        4 beats         0.985   0.698
#
#      speechiness  acousticness  instrumentalness  liveness  valence  loudness  \
# 700       0.0341         0.142               0.0     0.321    0.914    -2.531
#
#        tempo  duration_ms  weeks_on_chart  streams  duration_min
# 700  119.959       158000               1  6882424      2.633333

# %% [markdown]
# - Lagu Botadinha Saliente milik MC Rogerinho adalah lagu yang paling menarik dan memiliki 6882424 streaming.
# - Danceability sebagian besar lagu berada dalam kisaran 0,65 hingga 0,85.

# %%
song_df['loudness'].value_counts()
# Out:
# loudness
# -4.673    8
# -6.257    8
# -6.865    7
# -5.098    6
# -5.445    6
#          ..
# -5.714    1
# -3.241    1
# -4.319    1
# -6.587    1
# -8.616    1
# Name: count, Length: 4255, dtype: int64

# %%
# Menampilkan diagram batang dari 50 nilai teratas 
song_df['artist_names']=song_df['artist_names'].str.replace('$','')
song_df['artist_names'].value_counts().head(50).plot.bar(figsize=(10,5))
# Out:
# <Axes: xlabel='artist_names'>

# %%
song_df['loudness'].mean()
# Out:
# -6.350666513127591

# %%
song_df.corr(numeric_only=True)
# Out:
#                   danceability    energy  speechiness  acousticness  \
# danceability          1.000000  0.132397     0.184578     -0.248447
# energy                0.132397  1.000000    -0.007855     -0.515303
# speechiness           0.184578 -0.007855     1.000000     -0.075279
# acousticness         -0.248447 -0.515303    -0.075279      1.000000
# instrumentalness     -0.081519 -0.069500    -0.048271      0.063984
# liveness             -0.081186  0.135981     0.055040     -0.045413
# valence               0.346597  0.375763     0.037357     -0.081847
# loudness              0.188109  0.727379    -0.064261     -0.427972
# tempo                -0.058747  0.095561     0.123775     -0.071007
# duration_ms          -0.155502  0.013937    -0.039070     -0.034989
# weeks_on_chart        0.015205  0.009613    -0.087384      0.004370
# streams               0.011551  0.001399    -0.085806      0.012926
# duration_min         -0.155502  0.013937    -0.039070     -0.034989
#
# ...
